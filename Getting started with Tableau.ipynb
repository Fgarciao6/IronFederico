# %%
import pandas as pd
import numpy as np
import datetime
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', None)
import re

# %%
data = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
#Create a barplot of the number of customers per Gender.

# %%
import seaborn as sns
from seaborn import barplot
df = data[["Gender", "Customer"]]
display(df)
sns.barplot(x = 'Gender', y = "Customer", data = df)
# Out:
#      Gender Customer
# 0         F  BU79786
# 1         F  QZ44356
# 2         F  AI49188
# 3         M  WW63253
# 4         M  HB64268
# ...     ...      ...
# 9129      M  LA72316
# 9130      F  PK87824
# 9131      M  TD14365
# 9132      M  UP19263
# 9133      M  Y167826
#
# [9134 rows x 2 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jh/xz8c361s5l5d9_1ct6s4mw940000gn/T/ipykernel_42435/1896793462.py in <module>
#       3 df = data[["Gender", "Customer"]]
#       4 display(df)
# ----> 5 sns.barplot(x = 'Gender', y = "Customer", data = df)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
ax = sns.countplot(x="Gender", data=df, palette="Set3",order = data['Gender'].value_counts().index)

# %%
#https://public.tableau.com/app/profile/federico6734/viz/unit-4-lab1_tbwx_16481233082830/Hoja1?publish=yes

# %%
#https://public.tableau.com/app/profile/federico6734/viz/unit-4-lab_tbwx_16481232592280/Hoja2?publish=yes
