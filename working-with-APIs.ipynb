# %%
import requests
import pandas as pd

# %%
headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': "9613ca6ca5msh62659872159916fp1a0a2cjsndd9a3e6ff324"
    }

# %%
def get_airport_stats(airport):
    """
    Function to get stats for a given airport
    
    params:
    - airport: Airport code
    
    returns:
    - stats about the aiport
    """
    url = f"https://aerodatabox.p.rapidapi.com/airports/icao/{airport}/stats/routes/daily"
    response = requests.request("GET", url, headers=headers)
    
    result = pd.json_normalize(response.json()['routes'])
    return result

# %%
url_airports = "https://aerodatabox.p.rapidapi.com/health/services/feeds/FlightSchedules/airports"
response_airports = requests.get(url_airports, headers=headers)

airports = response_airports.json()['items']

# %%
get_airport_stats(airport='KLAX')
# Out:
#      averageDailyFlights                                          operators  \
# 0                  29.43  [{'name': 'American'}, {'name': 'Delta Air Lin...
# 1                  27.67  [{'name': 'United'}, {'name': 'Alaska'}, {'nam...
# 2                  25.45  [{'name': 'Southwest'}, {'name': 'Advanced Air...
# 3                  17.09  [{'name': 'JetBlue Airways'}, {'name': 'United...
# 4                  17.04  [{'name': 'American'}, {'name': 'Spirit'}, {'n...
# ..                   ...                                                ...
# 213                 0.14                                  [{'name': 'AXY'}]
# 214                 0.14                                  [{'name': 'LXJ'}]
# 215                 0.14                                  [{'name': 'VJT'}]
# 216                 0.14                                  [{'name': 'HRT'}]
# 217                 0.14                               [{'name': 'Alaska'}]
#
# ...
